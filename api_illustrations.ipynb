# %% [markdown]
# *Chunk Jokes and https://www.alphavantage.co for stock data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import seaborn as sns
import urllib
import json

import urllib.request
import urllib.request, urllib.parse, urllib.error

# %%
# chunk website
url = 'https://api.chucknorris.io/jokes/random'
user_agent = 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'

#url = "http://en.wikipedia.org/wiki/List_of_TCP_and_UDP_port_numbers"
headers={'User-Agent':user_agent,} 

request=urllib.request.Request(url,None,headers) #The assembled request
response = urllib.request.urlopen(request)
data = response.read() # The data u need

# %%
data
# Out:
# b'{"categories":[],"created_at":"2020-01-05 13:42:30.480041","icon_url":"https://assets.chucknorris.host/img/avatar/chuck-norris.png","id":"jDW-Of09QKyxFC7-2ExH3Q","updated_at":"2020-01-05 13:42:30.480041","url":"https://api.chucknorris.io/jokes/jDW-Of09QKyxFC7-2ExH3Q","value":"The time was afraid to go by fast because it didn\'t wanna be ahead of Chuck Norris."}'

# %%
data = json.loads( data)

# %%
data
# Out:
# {'categories': [],
#  'created_at': '2020-01-05 13:42:30.480041',
#  'icon_url': 'https://assets.chucknorris.host/img/avatar/chuck-norris.png',
#  'id': 'jDW-Of09QKyxFC7-2ExH3Q',
#  'updated_at': '2020-01-05 13:42:30.480041',
#  'url': 'https://api.chucknorris.io/jokes/jDW-Of09QKyxFC7-2ExH3Q',
#  'value': "The time was afraid to go by fast because it didn't wanna be ahead of Chuck Norris."}

# %%
# get category
url = 'https://api.chucknorris.io/jokes/categories'

# %%
def getdata(url):
  user_agent = 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'

  #url = "http://en.wikipedia.org/wiki/List_of_TCP_and_UDP_port_numbers"
  headers={'User-Agent':user_agent,} 

  request=urllib.request.Request(url,None,headers) #The assembled request
  response = urllib.request.urlopen(request)
  data = response.read() # The data u need
  data = json.loads(data)
  return data

# %%
categories = getdata(url)

# %%
categories
# Out:
# ['animal',
#  'career',
#  'celebrity',
#  'dev',
#  'explicit',
#  'fashion',
#  'food',
#  'history',
#  'money',
#  'movie',
#  'music',
#  'political',
#  'religion',
#  'science',
#  'sport',
#  'travel']

# %%
# !pip install alpha_vantage
# Out:
# Collecting alpha_vantage
#   Downloading https://files.pythonhosted.org/packages/12/e3/72ec32d859a363c2eebaa42e0d4abb5ac7172a7a77a2307576ceb5fc1b42/alpha_vantage-2.2.0.tar.gz
# Collecting aiohttp
#   Downloading https://files.pythonhosted.org/packages/7c/39/7eb5f98d24904e0f6d3edb505d4aa60e3ef83c0a58d6fe18244a51757247/aiohttp-3.6.2-cp36-cp36m-manylinux1_x86_64.whl (1.2MB)
#      |████████████████████████████████| 1.2MB 4.0MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from alpha_vantage) (2.23.0)
# Requirement already satisfied: typing-extensions>=3.6.5; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from aiohttp->alpha_vantage) (3.6.6)
# Collecting async-timeout<4.0,>=3.0
#   Downloading https://files.pythonhosted.org/packages/e1/1e/5a4441be21b0726c4464f3f23c8b19628372f606755a9d2e46c187e65ec4/async_timeout-3.0.1-py3-none-any.whl
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->alpha_vantage) (19.3.0)
# Collecting idna-ssl>=1.0; python_version < "3.7"
#   Downloading https://files.pythonhosted.org/packages/46/03/07c4894aae38b0de52b52586b24bf189bb83e4ddabfe2e2c8f2419eec6f4/idna-ssl-1.1.0.tar.gz
# Collecting yarl<2.0,>=1.0
#   Downloading https://files.pythonhosted.org/packages/95/8f/0209fc5d975f839344c33c822ff2f7ef80f6b1e984673a5a68f960bfa583/yarl-1.4.2-cp36-cp36m-manylinux1_x86_64.whl (252kB)
#      |████████████████████████████████| 256kB 12.8MB/s
# Requirement already satisfied: chardet<4.0,>=2.0 in /usr/local/lib/python3.6/dist-packages (from aiohttp->alpha_vantage) (3.0.4)
# Collecting multidict<5.0,>=4.5
#   Downloading https://files.pythonhosted.org/packages/1a/95/f50352b5366e7d579e8b99631680a9e32e1b22adfa1629a8f23b1d22d5e2/multidict-4.7.6-cp36-cp36m-manylinux1_x86_64.whl (148kB)
#      |████████████████████████████████| 153kB 15.5MB/s
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->alpha_vantage) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->alpha_vantage) (2020.4.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->alpha_vantage) (1.24.3)
# Building wheels for collected packages: alpha-vantage, idna-ssl
#   Building wheel for alpha-vantage (setup.py) ... done
#   Created wheel for alpha-vantage: filename=alpha_vantage-2.2.0-cp36-none-any.whl size=25705 sha256=4ec4454b8b6741ef17c7a348a266530a858ed5d75b8ee7d9efe99f08e31f8ea1
#   Stored in directory: /root/.cache/pip/wheels/3a/fa/05/80b0afcbd2a4de8bd2a0c5cd77084e3d3a9cc12c48be9b7f84
#   Building wheel for idna-ssl (setup.py) ... done
#   Created wheel for idna-ssl: filename=idna_ssl-1.1.0-cp36-none-any.whl size=3162 sha256=f56f2a5564d59401e86cf52803254ea0cc71d07c328b38da7c0836804181bd2a
#   Stored in directory: /root/.cache/pip/wheels/d3/00/b3/32d613e19e08a739751dd6bf998cfed277728f8b2127ad4eb7
# Successfully built alpha-vantage idna-ssl
# Installing collected packages: async-timeout, idna-ssl, multidict, yarl, aiohttp, alpha-vantage
# Successfully installed aiohttp-3.6.2 alpha-vantage-2.2.0 async-timeout-3.0.1 idna-ssl-1.1.0 multidict-4.7.6 yarl-1.4.2

# %%
from alpha_vantage.timeseries import TimeSeries
import json
# Your key here
key = 'XXXXXXXXXXXXXX'

def getdata(ticker):
  #user_agent = 'Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.9.0.7) Gecko/2009021910 Firefox/3.0.7'

  ts = TimeSeries(key)
  stock, meta = ts.get_daily(symbol=ticker)
  print(stock)
  stock = pd.DataFrame.from_dict(stock)
  print(stock)
  return stock

# %%
getdata('goog')
# Out:
# {'2020-05-19': {'1. open': '1387.0000', '2. high': '1392.0000', '3. low': '1373.4800', '4. close': '1373.4800', '5. volume': '1271509'}, '2020-05-18': {'1. open': '1361.7500', '2. high': '1392.3300', '3. low': '1354.2500', '4. close': '1383.9400', '5. volume': '1823964'}, '2020-05-15': {'1. open': '1350.0000', '2. high': '1374.4800', '3. low': '1339.0000', '4. close': '1373.1900', '5. volume': '1707747'}, '2020-05-14': {'1. open': '1335.0200', '2. high': '1357.4200', '3. low': '1323.9100', '4. close': '1356.1300', '5. volume': '1603077'}, '2020-05-13': {'1. open': '1377.0500', '2. high': '1385.4800', '3. low': '1328.4000', '4. close': '1349.3300', '5. volume': '1812585'}, '2020-05-12': {'1. open': '1407.1200', '2. high': '1415.0000', '3. low': '1374.7700', '4. close': '1375.7400', '5. volume': '1390600'}, '2020-05-11': {'1. open': '1378.2800', '2. high': '1416.5300', '3. low': '1377.1500', '4. close': '1403.2600', '5. volume': '1412116'}, '2020-05-08': {'1. open': '1383.1300', '2. high': '1398.7600', '3. low': '1375.4800', '4. close': '1388.3700', '5. volume': '1388068'}, '2020-05-07': {'1. open': '1365.9400', '2. high': '1377.6000', '3. low': '1355.2700', '4. close': '1372.5600', '5. volume': '1399759'}, '2020-05-06': {'1. open': '1361.6900', '2. high': '1371.1200', '3. low': '1347.2900', '4. close': '1347.3000', '5. volume': '1215423'}, '2020-05-05': {'1. open': '1337.9200', '2. high': '1373.9400', '3. low': '1337.4600', '4. close': '1351.1100', '5. volume': '1651533'}, '2020-05-04': {'1. open': '1308.2300', '2. high': '1327.6600', '3. low': '1299.0000', '4. close': '1326.8000', '5. volume': '1504017'}, '2020-05-01': {'1. open': '1328.5000', '2. high': '1352.0700', '3. low': '1311.0000', '4. close': '1320.6100', '5. volume': '2072639'}, '2020-04-30': {'1. open': '1324.8800', '2. high': '1352.8200', '3. low': '1322.4900', '4. close': '1348.6600', '5. volume': '2668906'}, '2020-04-29': {'1. open': '1341.4600', '2. high': '1359.9900', '3. low': '1325.3400', '4. close': '1341.4800', '5. volume': '3793630'}, '2020-04-28': {'1. open': '1287.9300', '2. high': '1288.0500', '3. low': '1232.2000', '4. close': '1233.6700', '5. volume': '2951309'}, '2020-04-27': {'1. open': '1296.0000', '2. high': '1296.1500', '3. low': '1269.0000', '4. close': '1275.8800', '5. volume': '1600563'}, '2020-04-24': {'1. open': '1261.1700', '2. high': '1280.4000', '3. low': '1249.4500', '4. close': '1279.3100', '5. volume': '1640394'}, '2020-04-23': {'1. open': '1271.5500', '2. high': '1293.3100', '3. low': '1265.6700', '4. close': '1276.3100', '5. volume': '1566203'}, '2020-04-22': {'1. open': '1245.5400', '2. high': '1285.6100', '3. low': '1242.0000', '4. close': '1263.2100', '5. volume': '2093140'}, '2020-04-21': {'1. open': '1247.0000', '2. high': '1254.2700', '3. low': '1209.7100', '4. close': '1216.3400', '5. volume': '2153003'}, '2020-04-20': {'1. open': '1271.0000', '2. high': '1281.6000', '3. low': '1261.3700', '4. close': '1266.6100', '5. volume': '1695488'}, '2020-04-17': {'1. open': '1284.8500', '2. high': '1294.4300', '3. low': '1271.2300', '4. close': '1283.2500', '5. volume': '1949042'}, '2020-04-16': {'1. open': '1274.1000', '2. high': '1279.0000', '3. low': '1242.6200', '4. close': '1263.4700', '5. volume': '2518099'}, '2020-04-15': {'1. open': '1245.6100', '2. high': '1280.4600', '3. low': '1240.4000', '4. close': '1262.4700', '5. volume': '1671703'}, '2020-04-14': {'1. open': '1245.0900', '2. high': '1282.0700', '3. low': '1236.9300', '4. close': '1269.2300', '5. volume': '2470353'}, '2020-04-13': {'1. open': '1209.1800', '2. high': '1220.5100', '3. low': '1187.6000', '4. close': '1217.5600', '5. volume': '1739828'}, '2020-04-09': {'1. open': '1224.0800', '2. high': '1225.5700', '3. low': '1196.7400', '4. close': '1211.4500', '5. volume': '2175421'}, '2020-04-08': {'1. open': '1206.5000', '2. high': '1219.0700', '3. low': '1188.1600', '4. close': '1210.2800', '5. volume': '1975135'}, '2020-04-07': {'1. open': '1221.0000', '2. high': '1225 ...
#           2020-05-19 2020-05-18 2020-05-15  ... 2019-12-30 2019-12-27 2019-12-26
# 1. open    1387.0000  1361.7500  1350.0000  ...  1350.0000  1362.9900  1346.1700
# 2. high    1392.0000  1392.3300  1374.4800  ...  1353.0000  1364.5300  1361.3300
# 3. low     1373.4800  1354.2500  1339.0000  ...  1334.0200  1349.3100  1344.4700
# 4. close   1373.4800  1383.9400  1373.1900  ...  1336.1400  1351.8900  1360.4000
# 5. volume    1271509    1823964    1707747  ...    1051323    1038718     667754
#
# [5 rows x 100 columns]
#           2020-05-19 2020-05-18 2020-05-15  ... 2019-12-30 2019-12-27 2019-12-26
# 1. open    1387.0000  1361.7500  1350.0000  ...  1350.0000  1362.9900  1346.1700
# 2. high    1392.0000  1392.3300  1374.4800  ...  1353.0000  1364.5300  1361.3300
# 3. low     1373.4800  1354.2500  1339.0000  ...  1334.0200  1349.3100  1344.4700
# 4. close   1373.4800  1383.9400  1373.1900  ...  1336.1400  1351.8900  1360.4000
# 5. volume    1271509    1823964    1707747  ...    1051323    1038718     667754
#
# [5 rows x 100 columns]
